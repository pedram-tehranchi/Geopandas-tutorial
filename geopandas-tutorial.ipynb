# %%
import geopandas as gpd
import geoalchemy2 as gs
import pandas as pd

# %% [markdown]
# ### Reading file

# %%
data = gpd.read_file('./data/Shapefiles/districts.shp')

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.head()
# Out:
#                                district  \
# 0                Newry, Mourne and Down
# 1                            Mid Ulster
# 2                   Mid and East Antrim
# 3               Lisburn and Castlereagh
# 4  Armagh City, Banbridge and Craigavon
#
#                                             geometry
# 0  POLYGON ((-5.82139 54.49408, -5.82128 54.49399...
# 1  POLYGON ((-6.53263 54.94913, -6.53253 54.94901...
# 2  POLYGON ((-5.96917 55.05284, -5.96909 55.05284...
# 3  POLYGON ((-6.08760 54.62414, -6.08699 54.62394...
# 4  POLYGON ((-6.27820 54.54965, -6.27819 54.54960...

# %% [markdown]
# <a>for visiting matplotlib color map click here:</a> <a href="https://matplotlib.org/users/colormap..."> click here  </a>

# %%
data.plot(cmap='jet', edgecolor='black', column='district')
# Out:
# <AxesSubplot:>

# %%
area = gpd.read_file('./data/Shapefiles/area_of_interest.shp')
area.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Checking coordinate reference system:

# %%
area.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
